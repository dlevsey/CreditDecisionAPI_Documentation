# %% [markdown]
# ## Generate Parameter Function

# %%
import csv

def gen_param_rst_from_csv(filename):
    
    filepath = filename
    if not filepath:
        return ""  # Return an empty string instead of None

    with open(filepath, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        rst_content = ""
        for row in reader:
            font_class = "parameter-requirement-required-font" if row["Requirement Status"] == "Required" else "parameter-requirement-optional-font"
            
            # Template for parameter
            template = """
<div class="parameter-item">
    <div class="name-and-requirement">
        <span class="parameter-name">{}</span>
        <span class="parameter-type">{}</span>
        <span class="{}">{}</span>
    </div>
    <span class="parameter-description">{}</span>
    <span class= "parameter-bottom-bar"></span>
</div>
""".format(row["Parameter"], row["Type"], font_class, row["Requirement Status"], row["Description"])

            # Wrap HTML content with RST - without changing its indentation
            rst_entry = ".. raw:: html\n\n    {}".format(template.replace('\n', '\n    ').strip())
            rst_content += rst_entry + "\n"

    return rst_content  # Return the RST content instead of printing it

# %% [markdown]
# ## Response Definition Function

# %%
import csv

def gen_resp_def_rst_from_csv(filename):
   
    filepath = filename
    if not filepath:
        return

    with open(filepath, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        rst_content = ""
        for row in reader:
            
            
            # splitting description based on '\n' and generating spans
            description_lines = row["Description"].split('\\n')
            description_spans = "\n    ".join([f'<span class="parameter-description">{line.strip()}</span>' for line in description_lines])

            # Template for parameter
            template = """
<div class="parameter-item">
    <div class="name-and-requirement">
        <span class="parameter-name">{}</span>
        <span class="parameter-type">{}</span>
       
    </div>
    {}
    <span class= "parameter-bottom-bar"></span>
</div>
""".format(row["Parameter"], row["Type"], description_spans)

            # wrap HTML content with the RST raw directive without changing its indentation
            rst_entry = ".. raw:: html\n\n    {}".format(template.replace('\n', '\n    ').strip())
            rst_content += rst_entry + "\n"

    # Print RST content
    print(rst_content)
    
    return rst_content

# %% [markdown]
# ###  Generate Get Shareholder Details Parameters

# %%
gen_param_rst_from_csv("get_shareholder_params-1027.csv")
# Out:
# .. raw:: html
#
#     <div class="parameter-item">
#         <span class="parameter-initial-bar"></span>
#         <div class="name-and-requirement">
#             <span class="parameter-name">CustomerShareholderId</span>
#             <span class="parameter-type">Number</span>
#             <span class="parameter-requirement-required-font">Required</span>
#         </div>
#         <span class="parameter-description">Refers to the ID for the Shareholder.</span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <span class="parameter-initial-bar"></span>
#         <div class="name-and-requirement">
#             <span class="parameter-name">SystemShareholderId</span>
#             <span class="parameter-type">Number</span>
#             <span class="parameter-requirement-required-font">Required</span>
#         </div>
#         <span class="parameter-description">Refers to the ID for the system.</span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <span class="parameter-initial-bar"></span>
#         <div class="name-and-requirement">
#             <span class="parameter-name">name</span>
#             <span class="parameter-type">String</span>
#             <span class="parameter-requirement-optional-font">Optional</span>
#         </div>
#         <span class="parameter-description">Include the name field in the response.</span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <span class="parameter-initial-bar"></span>
#         <div class="name-and-requirement">
#             <span class="parameter-name">address</span>
#             <span class="parameter-type">String</span>
#             <span class="parameter-requirement-optional-font">Optional</span>
#         </div>
#         <span class="parameter-description">Include the address field in the response.</span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <span class="parameter-initial-bar"></span>
#         <div class="name-and-requirement">
#             <span class="parameter-name">SSN</span>
#             <span class="parameter-type">String</span>
#             <span class="parameter-requirement-optional-font">Optional</span>
#         </div>
#         <span class="parameter-description">Include the SSN field in the response.</span>
#     </div>

# %% [markdown]
# ### Get Shareholder Response Defintions

# %%
gen_resp_def_rst_from_csv("response-definitions.csv")
# Out:
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">sortName</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">sort Name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">customerShareholderId</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">customer Shareholder Identifier in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">systemShareholderId</span>
#             <span class="parameter-type">int</span>
#
#         </div>
#         <span class="parameter-description">system Shareholder Identifier in integer format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">displayShareholderId</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">display Shareholder Identifier in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">name</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">fullPrimaryAddress</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">full Primary Address information in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.address1</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">address1 in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.address2</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">address2 in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.city</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">City name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.state</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">State or region in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.postalCode</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">postal Code in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.country2Code</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">country2 Code in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.email</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Email address in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.phone</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Phone number in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.secondaryPhone</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">secondary Phone in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.country</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Country name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">fullMailingAddress</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">full Mailing Address information in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.address1</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">address1 in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.address2</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">address2 in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.city</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">City name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.state</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">State or region in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.postalCode</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">postal Code in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.country2Code</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">country2 Code in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.email</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Email address in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.phone</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Phone number in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.secondaryPhone</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">secondary Phone in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.country</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Country name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">type</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Type information in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryTaxId</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">primary Tax Identifier in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryTaxIdType</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">primary Tax Identifier Type in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryPayeeName</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">primary Payee Name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">secondaryTaxId</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">secondary Tax Identifier in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">secondaryTaxIdType</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">secondary Tax Identifier Type in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">secondaryPayeeName</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">secondary Payee Name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# '.. raw:: html\n\n    <div class="parameter-item">\n        <div class="name-and-requirement">\n            <span class="parameter-name">sortName</span>\n            <span class="parameter-type">string</span>\n           \n        </div>\n        <span class="parameter-description">sort Name in string format.</span>\n        <span class= "parameter-bottom-bar"></span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <div class="name-and-requirement">\n            <span class="parameter-name">customerShareholderId</span>\n            <span class="parameter-type">string</span>\n           \n        </div>\n        <span class="parameter-description">customer Shareholder Identifier in string format.</span>\n        <span class= "parameter-bottom-bar"></span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <div class="name-and-requirement">\n            <span class="parameter-name">systemShareholderId</span>\n            <span class="parameter-type">int</span>\n           \n        </div>\n        <span class="parameter-description">system Shareholder Identifier in integer format.</span>\n        <span class= "parameter-bottom-bar"></span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <div class="name-and-requirement">\n            <span class="parameter-name">displayShareholderId</span>\n            <span class="parameter-type">string</span>\n           \n        </div>\n        <span class="parameter-description">display Shareholder Identifier in string format.</span>\n        <span class= "parameter-bottom-bar"></span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <div class="name-and-requirement">\n            <span class="parameter-name">name</span>\n            <span class="parameter-type">string</span>\n           \n        </div>\n        <span class="parameter-description">name in string format.</span>\n        <span class= "parameter-bottom-bar"></span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <div class="name-and-requirement">\n            <span class="parameter-name">fullPrimaryAddress</span>\n            <span class="parameter-type">string</span>\n           \n        </div>\n        <span class="parameter-description">full Primary Address information in string format.</span>\n        <span class= "parameter-bottom-bar"></span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <div class="name-and-requirement">\n            <span class="parameter-name">primaryAddress.address1</span>\n            <span class="parameter-type">string</span>\n           \n        </div>\n        <span class="parameter-description">address1 in string format.</span>\n        <span class= "parameter-bottom-bar"></span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <div class="name-and-requirement">\n            <span class="parameter-name">primaryAddress.address2</span>\n            <span class="parameter-type">string</span>\n           \n        </div>\n        <span class="parameter-description">address2 in string format.</span>\n        <span class= "parameter-bottom-bar"></span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <div class="name-and-requirement">\n            <span class="parameter-name">primaryAddress.city</span>\n            <span class="parameter-type">string</span>\n           \n        </div>\n        <span class="parameter-description">City name in string format.</span>\n        <span class= "parameter-bottom-bar"></span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <div class="name-and-requirement">\n            <span class="parameter-name">primaryAddress.state</span>\n            <span class="parameter-type">string</span>\n           \n        </div>\n        <span class="parameter-description">State or region in string format.</span>\n        <span class= "parameter-bottom-bar"></span>\n    ...

# %%
# !pip install pyperclip
# Out:
# Requirement already satisfied: pyperclip in c:\users\workpc\anaconda3\lib\site-packages (1.8.2)

# %%
import pyperclip

# %%
pyperclip.copy(gen_resp_def_rst_from_csv("response-definitions.csv"))
# Out:
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">sortName</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">sort Name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">customerShareholderId</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">customer Shareholder Identifier in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">systemShareholderId</span>
#             <span class="parameter-type">int</span>
#
#         </div>
#         <span class="parameter-description">system Shareholder Identifier in integer format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">displayShareholderId</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">display Shareholder Identifier in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">name</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">fullPrimaryAddress</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">full Primary Address information in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.address1</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">address1 in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.address2</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">address2 in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.city</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">City name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.state</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">State or region in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.postalCode</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">postal Code in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.country2Code</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">country2 Code in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.email</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Email address in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.phone</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Phone number in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.secondaryPhone</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">secondary Phone in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryAddress.country</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Country name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">fullMailingAddress</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">full Mailing Address information in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.address1</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">address1 in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.address2</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">address2 in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.city</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">City name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.state</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">State or region in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.postalCode</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">postal Code in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.country2Code</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">country2 Code in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.email</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Email address in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.phone</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Phone number in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.secondaryPhone</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">secondary Phone in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">mailingAddress.country</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Country name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">type</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">Type information in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryTaxId</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">primary Tax Identifier in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryTaxIdType</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">primary Tax Identifier Type in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">primaryPayeeName</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">primary Payee Name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">secondaryTaxId</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">secondary Tax Identifier in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">secondaryTaxIdType</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">secondary Tax Identifier Type in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">secondaryPayeeName</span>
#             <span class="parameter-type">string</span>
#
#         </div>
#         <span class="parameter-description">secondary Payee Name in string format.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>

# %% [markdown]
# ## Get Shareholder/GetHoldingSummary

# %% [markdown]
# #####  Request Parameters

# %%
gen_param_rst_from_csv('GetHoldingSummaryTHISONE.csv')
# Out:
# '.. raw:: html\n\n    <div class="parameter-item">\n        <span class="parameter-initial-bar"></span>\n        <div class="name-and-requirement">\n            <span class="parameter-name">CustomerIssuerId</span>\n            <span class="parameter-type"> Number</span>\n            <span class="parameter-requirement-optional-font"> Required</span>\n        </div>\n        <span class="parameter-description"> Not sure.</span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <span class="parameter-initial-bar"></span>\n        <div class="name-and-requirement">\n            <span class="parameter-name">SystemControlIssuerId</span>\n            <span class="parameter-type"> Number</span>\n            <span class="parameter-requirement-optional-font"> Required</span>\n        </div>\n        <span class="parameter-description"> Not sure.</span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <span class="parameter-initial-bar"></span>\n        <div class="name-and-requirement">\n            <span class="parameter-name">CustomerShareholderId</span>\n            <span class="parameter-type">Number</span>\n            <span class="parameter-requirement-required-font">Required</span>\n        </div>\n        <span class="parameter-description">Refers to the ID for the Shareholder.</span>\n    </div>\n.. raw:: html\n\n    <div class="parameter-item">\n        <span class="parameter-initial-bar"></span>\n        <div class="name-and-requirement">\n            <span class="parameter-name">SystemShareholderId</span>\n            <span class="parameter-type"></span>\n            <span class="parameter-requirement-required-font">Required</span>\n        </div>\n        <span class="parameter-description">Refers to the ID for the system - But maybe not. Not sure.</span>\n    </div>\n'

# %%
pyperclip.copy(gen_param_rst_from_csv('GetHoldingSummaryTHISONE.csv'))

# %% [markdown]
# #####  Response Definitions

# %%
gen_resp_def_rst_from_csv('GetHoldingSummaryTHISONE.csv')
pyperclip.copy(gen_resp_def_rst_from_csv('GetHoldingSummaryTHISONE.csv'))
# Out:
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">CustomerIssuerId</span>
#             <span class="parameter-type"> Number</span>
#
#         </div>
#         <span class="parameter-description">Not sure.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">SystemControlIssuerId</span>
#             <span class="parameter-type"> Number</span>
#
#         </div>
#         <span class="parameter-description">Not sure.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">CustomerShareholderId</span>
#             <span class="parameter-type">Number</span>
#
#         </div>
#         <span class="parameter-description">Refers to the ID for the Shareholder.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">SystemShareholderId</span>
#             <span class="parameter-type"></span>
#
#         </div>
#         <span class="parameter-description">Refers to the ID for the system - But maybe not. Not sure.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
#
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">CustomerIssuerId</span>
#             <span class="parameter-type"> Number</span>
#
#         </div>
#         <span class="parameter-description">Not sure.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">SystemControlIssuerId</span>
#             <span class="parameter-type"> Number</span>
#
#         </div>
#         <span class="parameter-description">Not sure.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">CustomerShareholderId</span>
#             <span class="parameter-type">Number</span>
#
#         </div>
#         <span class="parameter-description">Refers to the ID for the Shareholder.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
# .. raw:: html
#
#     <div class="parameter-item">
#         <div class="name-and-requirement">
#             <span class="parameter-name">SystemShareholderId</span>
#             <span class="parameter-type"></span>
#
#         </div>
#         <span class="parameter-description">Refers to the ID for the system - But maybe not. Not sure.</span>
#         <span class= "parameter-bottom-bar"></span>
#     </div>
